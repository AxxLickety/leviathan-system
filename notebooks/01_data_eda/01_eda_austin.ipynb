# %%
from src.features.affordability import attach_affordability_features

df2 = attach_affordability_features(df)
df2.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 3
#       1 from src.features.affordability import attach_affordability_features
# ----> 3 df2 = attach_affordability_features(df)
#       4 df2.head()
#
# NameError: name 'df' is not defined
